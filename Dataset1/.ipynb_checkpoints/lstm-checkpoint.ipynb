# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# load data
data_1 = pd.read_csv("datatraining.csv")
data_2 = pd.read_csv("datatest.csv")
data_3 = pd.read_csv("datatest2.csv")

uci_data = pd.concat([data_1, data_2, data_3])
uci_data.date = pd.to_datetime(uci_data.date)
uci_data.set_index('date', inplace=True)

# %% [markdown]
# # Resampling

# %%
uci_sampling = uci_data.resample('5min').mean()

# %% [markdown]
# # Fill Missing Value

# %%
uci_sampling = uci_sampling.interpolate(method ='linear', limit_direction ='forward')

# %%
uci_sampling = uci_sampling.drop (columns = ['Occupancy'])
# uci_sampling['Occupancy'] = uci_sampling['Occupancy'].apply(np.ceil)

# %% [markdown]
# # Normalize

# %%
def normalize(dataset):
    dataNorm=((dataset-dataset.min())/(dataset.max() - dataset.min()))
#     dataNorm['Occupancy'] = dataset['Occupancy']
    return dataNorm

# %%
datanorm = normalize(uci_sampling)

# %% [markdown]
# # Prepare Data

# %%
datanorm.head()
# Out:
#                      Temperature  Humidity     Light       CO2  HumidityRatio
# date
# 2015-02-02 14:15:00     0.877034  0.417928  0.510615  0.210149       0.552324
# 2015-02-02 14:20:00     0.883176  0.414520  0.465961  0.224784       0.551078
# 2015-02-02 14:25:00     0.883585  0.421105  0.441076  0.241023       0.558496
# 2015-02-02 14:30:00     0.875340  0.436627  0.413205  0.264918       0.572176
# 2015-02-02 14:35:00     0.863731  0.450744  0.404888  0.299943       0.582832

# %%
input_feature = datanorm.iloc[:,[0,1,2,3,4]].values
input_data = input_feature

# %%
lookback= 12
train_size = int(.8 * len(datanorm))
test_size=int(.2 * len(datanorm))
X=[]
y=[]
for i in range(len(datanorm)-lookback-1):
    t=[]
    for j in range(0,lookback):
        
        t.append(input_data[[(i+j)], :])
    X.append(t)
    y.append(input_data[i+ lookback,:5])

# %%
train_size
# Out:
# 3639

# %%
X, y= np.array(X), np.array(y)
X_train, y_train = X[:train_size+lookback], y[:train_size+lookback] 
X_test, y_test = X[:test_size+lookback], y[:test_size+lookback] 
X = X.reshape(X.shape[0],lookback, 5)
X_train = X_train.reshape(X_train.shape[0],lookback, 5)
X_test = X_test.reshape(X_test.shape[0],lookback, 5)
print(X.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4536, 12, 5)
# (921, 12, 5)
# (921, 5)

# %% [markdown]
# # LSTM

# %%
from keras import Sequential
from keras.layers import Dense, LSTM
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(LSTM(units=84, activation='relu', return_sequences = True, input_shape=(X.shape[1], 5)))
model.add(LSTM(units=84, activation='relu'))
model.add(Dense(units=5, activation='relu'))
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 14:48:14.566851 15476 deprecation_wrapper.py:119] From C:\Users\Jesica\Anaconda3\envs\gpu\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 14:48:14.579831 15476 deprecation_wrapper.py:119] From C:\Users\Jesica\Anaconda3\envs\gpu\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0904 14:48:14.582808 15476 deprecation_wrapper.py:119] From C:\Users\Jesica\Anaconda3\envs\gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 12, 84)            30240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 84)                56784
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 425
# =================================================================
# Total params: 87,449
# Trainable params: 87,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'mape', 'acc'])
# Out:
# W0904 14:48:19.046881 15476 deprecation_wrapper.py:119] From C:\Users\Jesica\Anaconda3\envs\gpu\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_
-04 - mean_absolute_error: 0.0081 - mean_absolute_percentage_error: 205476.4454 - acc: 0.9677
# Epoch 93/100
# 3651/3651 [==============================] - 1s 317us/step - loss: 3.3763e-04 - mean_squared_error: 3.3763e-04 - mean_absolute_error: 0.0082 - mean_absolute_percentage_error: 210817.8312 - acc: 0.9636
# Epoch 94/100
# 3651/3651 [==============================] - 1s 317us/step - loss: 3.3500e-04 - mean_squared_error: 3.3500e-04 - mean_absolute_error: 0.0081 - mean_absolute_percentage_error: 207898.5038 - acc: 0.9649
# Epoch 95/100
# 3651/3651 [==============================] - 1s 320us/step - loss: 3.3829e-04 - mean_squared_error: 3.3829e-04 - mean_absolute_error: 0.0087 - mean_absolute_percentage_error: 198522.2621 - acc: 0.9603
# Epoch 96/100
# 3651/3651 [==============================] - 1s 319us/step - loss: 3.3573e-04 - mean_squared_error: 3.3573e-04 - mean_absolute_error: 0.0083 - mean_absolute_percentage_error: 206607.1868 - acc: 0.96360s - loss: 3.1352e-04 - mean_squared_error: 3.1352e-04 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 16019
# Epoch 97/100
# 3651/3651 [==============================] - 1s 320us/step - loss: 3.5033e-04 - mean_squared_error: 3.5033e-04 - mean_absolute_error: 0.0090 - mean_absolute_percentage_error: 239902.2484 - acc: 0.9690
# Epoch 98/100
# 3651/3651 [==============================] - 1s 324us/step - loss: 3.3060e-04 - mean_squared_error: 3.3060e-04 - mean_absolute_error: 0.0083 - mean_absolute_percentage_error: 195370.0756 - acc: 0.9636
# Epoch 99/100
# 3651/3651 [==============================] - 1s 321us/step - loss: 3.2864e-04 - mean_squared_error: 3.2864e-04 - mean_absolute_error: 0.0081 - mean_absolute_percentage_error: 205048.3700 - acc: 0.9658
# Epoch 100/100
# 3651/3651 [==============================] - 1s 318us/step - loss: 3.1668e-04 - mean_squared_error: 3.1668e-04 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 173518.7637 - acc: 0.9682

# %%
predicted_value= model.predict(X_test)

# %%
predicted_value= model.predict(y_test)

# %%
datanorm.head()
# Out:
#                      Temperature  Humidity     Light       CO2  HumidityRatio  \
# date
# 2015-02-02 14:15:00     0.877034  0.417928  0.510615  0.210149       0.552324
# 2015-02-02 14:20:00     0.883176  0.414520  0.465961  0.224784       0.551078
# 2015-02-02 14:25:00     0.883585  0.421105  0.441076  0.241023       0.558496
# 2015-02-02 14:30:00     0.875340  0.436627  0.413205  0.264918       0.572176
# 2015-02-02 14:35:00     0.863731  0.450744  0.404888  0.299943       0.582832
#
#                      Occupancy
# date
# 2015-02-02 14:15:00        1.0
# 2015-02-02 14:20:00        1.0
# 2015-02-02 14:25:00        1.0
# 2015-02-02 14:30:00        1.0
# 2015-02-02 14:35:00        1.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(5):
    plt.plot(y_test[:, i], color='green')
    plt.plot(predicted_value[:, i], color= 'red')
#     plt.show()
# plt.title("Opening price of stocks sold")
# plt.xlabel("Time (latest-> oldest)")
# plt.ylabel("Stock Opening Price")
# plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
groups = [0,1,2,3,4]
labels = ['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio']
i = 1
plt.figure(figsize = (12,18))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(y_test[:, group], color='green')
    plt.plot(predicted_value[:, group], color= 'red', dashes = (5,5,5,5))
    plt.ylabel(labels[group])
    i += 1
# 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio'
# plt.title("IAQ Attributes",)
plt.xlabel("Time (latest-> oldest)")

plt.savefig('lstm acc.png')
plt.show()

# %% [markdown]
# # MAE

# %%
from sklearn.metrics import mean_absolute_error

acclist = []
for i in range (y_test.shape[1]):
    acc = mean_absolute_error(y_test[:, i],predicted_value[:, i])
    acclist.append(acc)
    
acclist_np = np.array(acclist)
np.mean(acclist_np)
# Out:
# 0.0079387772191456

# %% [markdown]
# # Denormalization

# %%
def denormalize(dataNorm, dataset):
    data = dataNorm * (dataset.max() - dataset.min()) + dataset.min()
    return data

# %%
denorm = []
for i in range (y_test.shape[1]):
    ytest = denormalize(predicted_value[:,i], uci_sampling.iloc[:, i])
    denorm.append(ytest)
denorm = np.array(denorm)

denorm = np.transpose(denorm)
denorm
# Out:
# array([[2.3365673e+01, 2.8407490e+01, 4.6259647e+02, 1.0625441e+03,
#         5.0871493e-03],
#        [2.3320709e+01, 2.8556387e+01, 4.6741058e+02, 1.0839008e+03,
#         5.0983643e-03],
#        [2.3276241e+01, 2.8689518e+01, 4.7466760e+02, 1.1044346e+03,
#         5.1078075e-03],
#        ...,
#        [2.1093054e+01, 1.9757271e+01, 0.0000000e+00, 5.0747562e+02,
#         3.0731671e-03],
#        [2.1077393e+01, 1.9664742e+01, 0.0000000e+00, 5.0114243e+02,
#         3.0555285e-03],
#        [2.1066248e+01, 1.9600004e+01, 0.0000000e+00, 4.9616818e+02,
#         3.0442853e-03]], dtype=float32)

# %%
denormy_test = []
for i in range (y_test.shape[1]):
    ytest = denormalize(y_test[:,i], uci_sampling.iloc[:, i])
    denormy_test.append(ytest)
denormy_test = np.array(denormy_test)

denormy_test = np.transpose(denormy_test)
denormy_test
# Out:
# array([[2.33860000e+01, 2.83018333e+01, 4.59000000e+02, 1.08568667e+03,
#         5.03822172e-03],
#        [2.33413889e+01, 2.84963889e+01, 4.69486111e+02, 1.10365278e+03,
#         5.05939353e-03],
#        [2.32900000e+01, 2.86703333e+01, 4.64850000e+02, 1.11562333e+03,
#         5.07462259e-03],
#        ...,
#        [2.11150000e+01, 1.95220000e+01, 0.00000000e+00, 5.02500000e+02,
#         3.01677148e-03],
#        [2.11375000e+01, 1.95562500e+01, 0.00000000e+00, 5.01541667e+02,
#         3.02625657e-03],
#        [2.11633333e+01, 1.94553333e+01, 0.00000000e+00, 4.95833333e+02,
#         3.01536012e-03]])

# %%
from sklearn.metrics import mean_absolute_error

acclist = []
for i in range (y_test.shape[1]):
    acc = mean_absolute_error(denormy_test[i, :],denorm[i, :])
    acclist.append(acc)
    
acclist_np = np.array(acclist)
np.mean(acclist_np)
# Out:
# 3.584976527151087

# %%
new_data = pd.DataFrame(columns=['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio'], data = denorm)

# %%
new_data.to_excel('prediction_new_rev.xlsx', engine='xlsxwriter', index=False)

# %%
new_data.to_excel('prediction_new.xlsx', engine='xlsxwriter', index=False)
